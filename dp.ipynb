# %%
import csv
import numpy as np
import folium

def build_dist_mat(input_list):
    n = 11
    dist_mat = np.zeros([n, n])
    for i in range(n):
        for j in range(i + 1, n):
            d = input_list[i, :] - input_list[j, :]
            # 计算点积
            dist_mat[i, j] = np.dot(d, d)
            dist_mat[j, i] = dist_mat[i, j]
    return dist_mat

def tsp_dp(graph):
    num_cities = len(graph)
    
    # dp[mask][i]表示已经访问过的城市集合为mask，当前所在的城市为i时的最短路径长度
    dp = [[float('inf')] * num_cities for _ in range(1 << num_cities)]
    
    # path[mask][i]表示从起始城市到当前城市的最短路径上的城市顺序
    path = [[[] for _ in range(num_cities)] for _ in range(1 << num_cities)]
    
    # 初始化，从起始城市出发，到达自身的距离为0
    dp[1][0] = 0
    path[1][0] = [0]
    
    # 遍历所有的状态
    for mask in range(1, 1 << num_cities):
        for i in range(num_cities):
            # 如果当前城市不在mask中，则跳过
            if not (mask & (1 << i)):
                continue
            
            # 遍历所有可能的上一个城市
            for j in range(num_cities):
                # 如果上一个城市在mask中，且当前城市与上一个城市不同
                if mask & (1 << j) and i != j:
                    if dp[mask][i] > dp[mask ^ (1 << i)][j] + graph[j][i]:
                        dp[mask][i] = dp[mask ^ (1 << i)][j] + graph[j][i]
                        path[mask][i] = path[mask ^ (1 << i)][j] + [i]
    
    # 找到最短路径
    mask = (1 << num_cities) - 1
    min_length = min(dp[mask][i] + graph[i][0] for i in range(1, num_cities))
    min_path = path[mask][[i for i in range(1, num_cities) if dp[mask][i] + graph[i][0] == min_length][0]] + [0]
    
    return min_length, min_path


sites = []

# Replace 'your_file_path.csv' with the actual path to your CSV file
with open('sites.csv', newline='') as csvfile:
    reader = csv.reader(csvfile)
    next(reader)  # Skip the header row
    for row in reader:
        latitude = float(row[1])
        longitude = float(row[2])
        sites.append([longitude, latitude])

sites_array = np.array(sites)
# 示例：使用邻接矩阵表示城市之间的距离
graph = build_dist_mat(sites_array)

result = tsp_dp(graph)
print("shortest path length:", result[0])

path = result[1]
print("shortest path:", path)
result_pos_list = sites_array[path, :]

result_pos_list[:, [0, 1]] = result_pos_list[:, [1, 0]]

m = folium.Map(location=(49.284, -123.125), zoom_start=14, tiles="cartodb positron")
for i in range(1,len(result_pos_list)):
    folium.Marker(
        location=result_pos_list[i],
        tooltip= path[i],
        icon=folium.Icon(icon="cloud",color="orange"),
    ).add_to(m)
folium.PolyLine(result_pos_list, tooltip="Route").add_to(m)
m
# Out:
# shortest path length: 0.0007155068920005456
# shortest path: [0, 10, 6, 1, 5, 2, 7, 3, 4, 9, 8, 0]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_79ad12376ddbe389146c62d54c935551 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_79ad12376ddbe389146c62d54c935551&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_79ad12376ddbe389146c62d54c935551 = L.map(
#                 &quot;map_79ad12376ddbe389146c62d54c935551&quot;,
#                 {
#                     center: [49.284, -123.125],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4041a569cee3d373b69ee17898985557 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_4041a569cee3d373b69ee17898985557.addTo(map_79ad12376ddbe389146c62d54c935551);
#
#
#             var marker_72a62315006d91d0b5c5ef00bcdd7277 = L.marker(
#                 [49.284437, -123.121212],
#                 {}
#             ).addTo(map_79ad12376ddbe389146c62d54c935551);
#
#
#             var icon_09c6befcec1b740451401abed3dae141 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_72a62315006d91d0b5c5ef00bcdd7277.setIcon(icon_09c6befcec1b740451401abed3dae141);
#
#
#             marker_72a62315006d91d0b5c5ef00bcdd7277.bindTooltip(
#                 `&lt;div&gt;
#                      10
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_d50c3eac4815378339c27997f086a91c = L.marker(
#                 [49.289084, -123.1225],
#                 {}
#             ).addTo(map_79ad12376ddbe389146c62d54c935551);
#
#
#             var icon_0a7e891c90becab3f995c7a862018b7a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d50c3eac4815378339c27997f086a91c.setIcon(icon_0a7e891c90becab3f995c7a862018b7a);
#
#
#             marker_d50c3eac4815378339c27997f086a91c.bindTooltip(
#                 `&lt;div&gt;
#                      6
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_af3d6842a8c7855be023c66af497df21 = L.marker(
#                 [49.290089, -123.132699],
#                 {}
#             ).addTo(map_79ad12376ddbe389146c62d54c935551);
#
#
#             var icon_65b91d6650fc345021084a1df2c61994 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_af3d6842a8c7855be023c66af497df21.setIcon(icon_65b91d6650fc345021084a1df2c61994);
#
#
#             marker_af3d6842a8c7855be023c66af497df21.bindTooltip(
#                 `&lt;div&gt;
#                      1
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c089c2d054aa6ecf19f7415e7ca45305 = L.marker(
#                 [49.285281, -123.138721],
#                 {}
#             ).addTo(map_79ad12376ddbe389146c62d54c935551);
#
#
#             var icon_95c63949f87f09acddb784a48bf48b47 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c089c2d054aa6ecf19f7415e7ca45305.setIcon(icon_95c63949f87f09acddb784a48bf48b47);
#
#
#             marker_c089c2d054aa6ecf19f7415e7ca45305.bindTooltip(
#                 `&lt;div&gt;
#                      5
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_120ea512b5b0c64f4f56b30a610d6043 = L.marker(
#                 [49.280699, -123.134289],
#                 {}
#             ).addTo(map_79ad12376ddbe389146c62d54c935551);
#
#
#             var icon_93627f266313febdbdd12095360138ee = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_120ea512b5b0c64f4f56b30a610d604
